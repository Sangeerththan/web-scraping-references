# %% [markdown]
# ### Import Packages

# %%
from selenium import webdriver
import pandas as pd 
import time

# %% [markdown]
# ### Set Up

# %%
driver = webdriver.Chrome(executable_path= 'C:\webdrivers\chromedriver.exe')
driver.get('https://www.yelp.com/search?find_desc=dentists&find_loc=San+Francisco%2C+CA&ns=1')

driver.maximize_window()
time.sleep(1)

# %% [markdown]
# ### Accept Cookies

# %%
# accept cookies
cookies = driver.find_element_by_id('onetrust-accept-btn-handler')

cookies.click()

# %% [markdown]
# ### Target The Data We Want To Scrape

# %%
# names
names =driver.find_elements_by_xpath('//h4[@class="css-1l5lt1i"]/span/a')

# telephone
telephone = driver.find_elements_by_xpath('//div[@class=" container__09f24__2th0K padding-l2__09f24__1jCR9 border-color--default__09f24__3Epto text-align--right__09f24__2w_vG"]/div/div/div/p')

# address
address = driver.find_elements_by_xpath('//address//span[@class=" raw__09f24__3Azrj"]')

# expertise
expertise = driver.find_elements_by_xpath('//div[@class=" border-color--default__09f24__3Epto"]/div/div/div/p')

# stars
stars = driver.find_elements_by_xpath('//div[@class=" attribute__09f24__1La1D display--inline-block__09f24__3SvIn margin-r1__09f24__3PebR border-color--default__09f24__3Epto"]/span/div')

# rating count
rating_count = driver.find_elements_by_xpath('//span[@class="reviewCount__09f24__3GsGY css-e81eai"]')

# %%
for r in rating_count:
    print(r.text)


# for s in stars:
#     print(s.get_attribute('aria-label'))
# Out:
# 33
# 13
# 123
# 47
# 68
# 46
# 71
# 306
# 444
# 228
# 343
# 118
# 67
# 111
# 108
# 77
# 95
# 132
# 46

# %% [markdown]
# ### Create Dataframe

# %%
dentist_example = pd.DataFrame(columns=['Name', 'Phone', 'Address'])

# %%
dentist_example
# Out:
# Empty DataFrame
# Columns: [Name, Phone, Address]
# Index: []

# %% [markdown]
# ### Empty Lists

# %% [markdown]
# 1. Loop through the results
# 2. Append the results in a list
# 3. Use this lists as the "value-pair" part for the dictionary (Remember: Dictionaries consist of Key-Value Pairs)
# 3. Hand this Dictionary over to the Pandas Dataframe

# %%
names_list = []
phone_list = []
address_list = []
expertise_list =[]
stars_list = []
rating_count_list = []

# %% [markdown]
# ### Loop and Append to List

# %%
for n in names:
    names_list.append(n.text)
    
for t in telephone:
    phone_list.append(t.text)

for a in address:
    address_list.append(a.text)
    
for e in expertise:
    expertise_list.append(e.text)

for s in stars:
    stars_list.append(s.get_attribute('aria-label'))

for r in rating_count:
    rating_count_list.append(r.text)

# %% [markdown]
# ### Dictionary

# %%
dent_dictionary = {'Name': names_list, 'Phone': phone_list, 'Address': address_list, 'Expertise': expertise_list,
                  'Stars': stars_list, 'Rating_Count': rating_count_list}

# %% [markdown]
# ### Dictionary to Pandas Dataframe

# %%
df = pd.DataFrame.from_dict (dent_dictionary)

# %%
# dataframe before cleaning
df
# Out:
#                                   Name           Phone              Address  \
# 0               William Schneider, DDS  (925) 378-2348   1855 San Miguel Dr
# 1                Franklin Dental Group  (415) 234-0480     2827 Franklin St
# 2             Polly Rivas & Associates  (415) 397-4827      260 Stockton St
# 3                 Rebecca E Armel, DDS  (415) 421-0317          490 Post St
# 4                     Caroline Le, DDS  (415) 398-2808        450 Sutter St
# 5                     Edward Loev, DMD  (415) 636-6419        450 Sutter St
# 6              Growney Maurice Jr, DDS  (415) 566-8500         790 Ulloa St
# 7                 Titus Tang, DDS MAGD  (628) 400-4716  59 B Serramonte Ctr
# 8                    All Smiles Dental  (415) 564-2200     156 W Portal Ave
# 9   Josh Berd, DDS - The Dentist Group  (415) 706-7687          90 Gough St
# 10       San Francisco Dental Artistry  (415) 399-0609          369 Pine St
# 11                     David T Ho, DDS  (415) 563-2700         1500 Bush St
# 12               Michael J Perona, DDS  (415) 546-7990         188 Spear St
# 13                Robert Phong Ho, DDS  (415) 386-0666         307 12th Ave
# 14   Aesthetic Dentistry of Noe Valley  (415) 285-7007         4162 24th St
# 15                   Zen Dental Studio  (415) 857-0150           254 5th St
# 16                Lakeside Dental Care  (415) 469-7777       2645 Ocean Ave
# 17                     Elias Qaré, DDS  (415) 282-5340      2480 Mission St
# 18                    Claude Sidi, DMD  (415) 391-9748        450 Sutter St
#
#                                             Expertise            Stars  \
# 0                    Orthodontists, General Dentistry    5 star rating
# 1   Cosmetic Dentists, General Dentistry, Endodont...    5 star rating
# 2   Cosmetic Dentists, Endodontists, General Denti...    4 star rating
# 3                General Dentistry, Cosmetic Dentists    5 star rating
# 4                Cosmetic Dentists, General Dentistry    5 star rating
# 5                                            Dentists    5 star rating
# 6                                   General Dentistry    5 star rating
# 7   Orthodontists, Cosmetic Dentists, General Dent...    5 star rating
# 8      General Dentistry, Endodontists, Orthodontists    5 star rating
# 9   Cosmetic Dentists, General Dentistry, Orthodon...  4.5 star rating
# 10               General Dentistry, Cosmetic Dentists    5 star rating
# 11                                  General Dentistry    5 star rating
# 12  General Dentistry, Cosmetic Dentists, Orthodon...    5 star rating
# 13                                  General Dentistry    5 star rating
# 14  Verified LicenseCosmetic Dentists, General Den...  4.5 star rating
# 15  General Dentistry, Cosmetic Dentists, Orthodon...    5 star rating
# 16                                  General Dentistry    5 star rating
# 17                                  General Dentistry    5 star rating
# 18  Cosmetic Dentists, General Dentistry, Endodont...    5 star rating
#
#    Rating_Count
# 0            33
# 1            13
# 2           123
# 3            46
# 4            47
# 5            71
# 6            46
# 7           306
# 8           444
# 9           228
# 10          343
# 11          118
# 12           67
# 13          111
# 14          108
# 15           77
# 16           95
# 17          132
# 18           58

# %% [markdown]
# ### Clean the Data

# %%
df['Stars'] = df['Stars'].apply(lambda x: x.replace('star rating', ''))

# %%
# dataframe after cleaning
df
# Out:
#                                   Name           Phone              Address  \
# 0               William Schneider, DDS  (925) 378-2348   1855 San Miguel Dr
# 1                Franklin Dental Group  (415) 234-0480     2827 Franklin St
# 2             Polly Rivas & Associates  (415) 397-4827      260 Stockton St
# 3                 Rebecca E Armel, DDS  (415) 421-0317          490 Post St
# 4                     Caroline Le, DDS  (415) 398-2808        450 Sutter St
# 5                     Edward Loev, DMD  (415) 636-6419        450 Sutter St
# 6              Growney Maurice Jr, DDS  (415) 566-8500         790 Ulloa St
# 7                 Titus Tang, DDS MAGD  (628) 400-4716  59 B Serramonte Ctr
# 8                    All Smiles Dental  (415) 564-2200     156 W Portal Ave
# 9   Josh Berd, DDS - The Dentist Group  (415) 706-7687          90 Gough St
# 10       San Francisco Dental Artistry  (415) 399-0609          369 Pine St
# 11                     David T Ho, DDS  (415) 563-2700         1500 Bush St
# 12               Michael J Perona, DDS  (415) 546-7990         188 Spear St
# 13                Robert Phong Ho, DDS  (415) 386-0666         307 12th Ave
# 14   Aesthetic Dentistry of Noe Valley  (415) 285-7007         4162 24th St
# 15                   Zen Dental Studio  (415) 857-0150           254 5th St
# 16                Lakeside Dental Care  (415) 469-7777       2645 Ocean Ave
# 17                     Elias Qaré, DDS  (415) 282-5340      2480 Mission St
# 18                    Claude Sidi, DMD  (415) 391-9748        450 Sutter St
#
#                                             Expertise Stars Rating_Count
# 0                    Orthodontists, General Dentistry    5            33
# 1   Cosmetic Dentists, General Dentistry, Endodont...    5            13
# 2   Cosmetic Dentists, Endodontists, General Denti...    4           123
# 3                General Dentistry, Cosmetic Dentists    5            46
# 4                Cosmetic Dentists, General Dentistry    5            47
# 5                                            Dentists    5            71
# 6                                   General Dentistry    5            46
# 7   Orthodontists, Cosmetic Dentists, General Dent...    5           306
# 8      General Dentistry, Endodontists, Orthodontists    5           444
# 9   Cosmetic Dentists, General Dentistry, Orthodon...  4.5           228
# 10               General Dentistry, Cosmetic Dentists    5           343
# 11                                  General Dentistry    5           118
# 12  General Dentistry, Cosmetic Dentists, Orthodon...    5            67
# 13                                  General Dentistry    5           111
# 14  Verified LicenseCosmetic Dentists, General Den...  4.5           108
# 15  General Dentistry, Cosmetic Dentists, Orthodon...    5            77
# 16                                  General Dentistry    5            95
# 17                                  General Dentistry    5           132
# 18  Cosmetic Dentists, General Dentistry, Endodont...    5            58

# %% [markdown]
# ### Save Data in Excel

# %%
df.to_excel('data_done.xlsx', index= False)
